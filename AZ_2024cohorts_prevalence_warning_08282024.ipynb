# %%
import io
import subprocess
import os
import glob
import sys
import pwd

import pandas as pd
import numpy as np
import scipy
import scipy.stats as stats
from sklearn.decomposition import PCA
import pickle
import re
import math
import plotnine as pn
import seaborn as sns
import glob
import subprocess
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from numpy import log
from collections import defaultdict,Counter
import re
import statsmodels
import warnings
import statsmodels.stats.multitest as smm
import json

from pathlib import Path
from midas import m
from datetime import datetime, date
import altair as alt

# gh specific
sys.path.append('/ghsfa/projects/pharma/shared_scripts/')
import bibp.functions as functions
import hgvslib.pHGVS as pHGVS  ## do a pull on the hgvslib git repo

# !pip install statannotations==0.4.0
# #!pip uninstall statannotations --yes
# from statannotations.Annotator import Annotator

warnings.filterwarnings("ignore")
pd.options.display.max_rows = None
pd.options.display.max_columns=None
pd.options.display.max_colwidth=None
work_dir="/ghsfa/projects/pharma/projects/sirius_pharma/hazhang_projects/AZ_2024cohorts_prevalence_warning_08282024"

# %% [markdown]
# # Pull all AZ batches from pharma data warehouse (Infinity, OMNI and G360)

# %%
# File name list to handle corner case of data readin
header1_list = [""]
header0_list = [
 '20230928_AstraZeneca_SOW164_46Samples_InfinityReport.csv',
 '20231106_AstraZeneca_SOW164_46Samples_InfinityReport.csv',
 '20231207_AstraZeneca_SOW170_188Samples_InfinityReport.csv',
 '20240111_AstraZeneca_SOW174_35Samples_InfinityReport.csv',
 '20240116_AstraZeneca_SOW182_40Samples_InfinityReport.csv',
 '20240422_AstraZeneca_SOW176Monitoring_998Samples_InfinityReport.csv',

]

# Define the folder paths
folders = [
    # "/ghsfa/projects/pharma/datawarehouse/Infinity", # This only include AZ batches before 2024
    "/ghsfa/projects/pharma/datawarehouse/infinity",
    "/ghsfa/projects/pharma/datawarehouse/data/infinity_ist_report_warehouse",
    "/ghsfa/projects/pharma/datawarehouse/data/infinity_mrd_report_warehouse",
    "/ghsfa/projects/pharma/datawarehouse/data/infinity_report_warehouse",

    "/ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902", # For G360
    "/ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse" #For OMNI

]

# List to store the dataframes for final merge
dfs = []

# Iterate over each folder
for folder in folders:
    # List all csv files in the folder
    for file in os.listdir(folder):
        file_path = os.path.join(folder, file)
        # Check if the file is a CSV
        if file.endswith('.csv') and "AstraZe" in file: # Becuase some batches were named as "AstraZenaca" instead of "AstraZeneca"
            try:
                # Determine the header row based on the presence of "MRD" in the filename
                # Some corner cases
                if file in header0_list:
                    df = pd.read_csv(file_path, header=0)
                elif file in header1_list:
                    df = pd.read_csv(file_path, header=1)
                elif "MRD" in file.upper():
                    df = pd.read_csv(file_path, header=0)
                elif "Reveal" in file:
                    df = pd.read_csv(file_path, header=0)
                else:
                    df = pd.read_csv(file_path, header=1)

                # Select specified columns, handling cases where some columns might not exist
                columns = ['Study_ID', 'GHRequestID', 'Customer_SampleID', 'Patient_ID', 'Visit_name', 'Max_percentage', 'Sample_status', 'Sample_comment', 'cfDNA_ng', 'Plasma_ml_input', 'Cancertype']
                df_sub = df.loc[:, df.columns.isin(columns)].copy()

                # Drop duplicates based on 'Customer_SampleID' instead of "GHSampleID" becuase some batches are missing this column
                df_sub_dedup = df_sub.drop_duplicates(subset=["Customer_SampleID"])

                # Add a column for the CSV file name
                df_sub_dedup['csv_file_name'] = file

                # Get the UID of the file owner and convert it to a username
                file_stats = os.stat(file_path)
                file_uid = file_stats.st_uid
                file_creator = pwd.getpwuid(file_uid).pw_name
                df_sub_dedup['file_creator'] = file_creator

                # Append the processed dataframe to the list
                dfs.append(df_sub_dedup)
            except pd.errors.ParserError:
                print(f"Error reading file: {file_path} - possibly incorrect header.")
            except Exception as e:
                print(f"An unexpected error occurred with file: {file_path} - {str(e)}")

# Merge all dataframes into a final DataFrame
df_merged = pd.concat(dfs, ignore_index=True)
df_merged.head()
# Out:
#       Study_ID Customer_SampleID GHRequestID Patient_ID Visit_name  \
# 0  D926NC00001        6219464014    A0890339   E5703003       SCRN
# 1  D926NC00001        6802134548    A0890340   E4303003       SCRN
# 2  D926NC00001        6219464013    A0890341   E5703001       SCRN
# 3  D926NC00001        6220345986    A0890342   E2617001       SCRN
# 4  D926NC00001        6604395135    A0890343   E6009008       SCRN
#
#   Sample_status Sample_comment  Max_percentage  cfDNA_ng Plasma_ml_input  \
# 0       SUCCESS            NaN             NaN     9.620             3.0
# 1       SUCCESS            NaN             NaN   119.600             3.5
# 2       SUCCESS            NaN             NaN     8.788             3.0
# 3       SUCCESS            NaN             NaN    13.000             3.5
# 4       SUCCESS            NaN             NaN     7.332             3.5
#
#   Cancertype                                         csv_file_name  \
# 0        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 1        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 2        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 3        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 4        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
#
#   file_creator
# 0     produser
# 1     produser
# 2     produser
# 3     produser
# 4     produser

# %% [markdown]
# ### DO NOT RUN! This is for sample checking. START CELL here

# %%
# File name list to handle corner case of data readin
header1_list = [""]
header0_list = [
 '20230928_AstraZeneca_SOW164_46Samples_InfinityReport.csv',
 '20231106_AstraZeneca_SOW164_46Samples_InfinityReport.csv',
 '20231207_AstraZeneca_SOW170_188Samples_InfinityReport.csv',
 '20240111_AstraZeneca_SOW174_35Samples_InfinityReport.csv',
 '20240116_AstraZeneca_SOW182_40Samples_InfinityReport.csv',
 '20240422_AstraZeneca_SOW176Monitoring_998Samples_InfinityReport.csv',

]

# Define the folder paths
folders = [
    # "/ghsfa/projects/pharma/datawarehouse/Infinity", # This only include AZ batches before 2024
    "/ghsfa/projects/pharma/datawarehouse/infinity",
    "/ghsfa/projects/pharma/datawarehouse/data/infinity_ist_report_warehouse",
    "/ghsfa/projects/pharma/datawarehouse/data/infinity_mrd_report_warehouse",
    "/ghsfa/projects/pharma/datawarehouse/data/infinity_report_warehouse",

    "/ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902", # For G360
    "/ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse" #For OMNI

]

# List to store the dataframes for final merge
dfs = []

# Iterate over each folder
for folder in folders:
    # List all csv files in the folder
    for file in os.listdir(folder):
        file_path = os.path.join(folder, file)
        # Check if the file is a CSV
        if file.endswith('.csv') and "AstraZe" in file: # Becuase some batches were named as "AstraZenaca" instead of "AstraZeneca"
            try:
                # Determine the header row based on the presence of "MRD" in the filename
                # Some corner cases
                if file in header0_list:
                    df = pd.read_csv(file_path, header=0)
                elif file in header1_list:
                    df = pd.read_csv(file_path, header=1)
                elif "MRD" in file.upper():
                    df = pd.read_csv(file_path, header=0)
                elif "Reveal" in file:
                    df = pd.read_csv(file_path, header=0)
                else:
                    df = pd.read_csv(file_path, header=1)

                # Select specified columns, handling cases where some columns might not exist
                columns = ['Study_ID', 'GHRequestID', 'GHSampleID', 'Patient_ID', 'Visit_name', 'Max_percentage', 'Sample_status', 'Sample_comment', 'cfDNA_ng', 'Plasma_ml_input', 'Cancertype']
                df_sub = df.loc[:, df.columns.isin(columns)].copy()

                # Drop duplicates based on 'Customer_SampleID' instead of "GHSampleID" becuase some batches are missing this column
                df_sub_dedup = df_sub.drop_duplicates(subset=["GHSampleID"])

                # Add a column for the CSV file name
                df_sub_dedup['csv_file_name'] = file

                # Get the UID of the file owner and convert it to a username
                file_stats = os.stat(file_path)
                file_uid = file_stats.st_uid
                file_creator = pwd.getpwuid(file_uid).pw_name
                df_sub_dedup['file_creator'] = file_creator

                # Append the processed dataframe to the list
                dfs.append(df_sub_dedup)
            except pd.errors.ParserError:
                print(f"Error reading file: {file_path} - possibly incorrect header.")
            except Exception as e:
                print(f"An unexpected error occurred with file: {file_path} - {str(e)}")

# Merge all dataframes into a final DataFrame
df_merged = pd.concat(dfs, ignore_index=True)
df_merged.head()
# Out:
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210912_AstraZeneca_SOW97_6Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210506_AstraZeneca_SOW90_17Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210825_AstraZeneca_SOW97_4Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210809_AstraZeneca_SOW66_28Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210720_AstraZeneca_SOW100_161Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210928_AstraZeneca_SOW103_24Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210722_AstraZeneca_SOW97_4Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210924_AstraZeneca_SOW16_Retrospective_144Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210719_AstraZeneca_SOW90_26Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20210624_AstraZeneca_SOW100_171Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/g360_reports_since_201902/20200914_AstraZeneca_SOW85_19Samples_G360Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210615_AstraZeneca_SOW40_38Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20201214_AstraZeneca_SOW68_12Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200527_AstraZeneca_SOW48_168Samples_OMNICDxReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20180626_AstraZeneca_SOW17_184Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210927_AstraZeneca_SOW80_127Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200107_AstraZeneca_SOW41_9Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20180517_AstraZeneca_SOW20_195Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210602_AstraZeneca_SOW80_141Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191113_AstraZeneca_SOW40_34Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190731_AstraZeneca_SOW62_8Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200923_AstraZeneca_SOW40_62Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191115_AstraZeneca_SOW41_8Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200724_AstraZeneca_SOW48_86Samples_OMNICDxReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200331_AstraZeneca_SOW41_19Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200506_AstraZeneca_SOW41_17_Samples_Omni_Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210504_AstraZeneca_SOW86_13Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210316_AstraZeneca_SOW40_44Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210618_AstraZeneca_SOW94_79Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190226_AstraZeneca_SOW26_OMNI_31Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190903_AstraZeneca_SOW62_6Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190828_AstraZeneca_SOW49_87Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200623_AstraZeneca_SOW46_21Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191224_AstraZeneca_SOW32_705Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20201201_AstraZeneca_SOW41_8Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210928_AstraZeneca_SOW107_31Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200311_AstraZeneca_SOW59_25Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190711_AstraZeneca_SOW47_17Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191226_AstraZeneca_SOW32_636Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210311_AstraZeneca_SOW41_1Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190619_AstraZeneca_SOW34_20Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210726_AstraZeneca_SOW86_6Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20201230_AstraZeneca_SOW74_36Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200219_AstraZeneca_SOW48_379Samples_OMNICDxReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191002_AstraZeneca_SOW50_5Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200630_AstraZeneca_SOW73_75Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190926_AstraZeneca_SOW28_126Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190515_AstraZeneca_SOW26_OMNI_10Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20180627_AstraZeneca_SOW17_99Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20201201_AstraZeneca_SOW41_2Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191001_AstraZeneca_SOW47_2Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191004_AstraZeneca_SOW49_168Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210324_AstraZeneca_SOW91_21Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200917_AstraZeneca_SOW50_4Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190918_AstraZeneca_SOW30_152Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200323_AstraZeneca_SOW69_10_Samples_Omni_Report.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191228_AstraZeneca_SOW32_434Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20201229_AstraZeneca_SOW40_34Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210218_AstraZeneca_SOW41_2Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190507_AstraZeneca_SOW21_72Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200205_AstraZeneca_SOW21_34Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200225_AstraZeneca_SOW56_38Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200911_AstraZeneca_SOW30_91Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20180410_AstraZeneca_SOW17_100Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200413_AstraZeneca_SOW69_45Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210210_AstraZeneca_SOW68_4Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200917_AstraZeneca_SOW41_10Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20201202_AstraZeneca_SOW87_30Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191106_AstraZeneca_SOW62_10Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210817_AstraZeneca_SOW84_20Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210908_AstraZeneca_SOW84_23Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200330_AstraZeneca_SOW64_1022Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210630_AstraZeneca_SOW74_57Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191127_AstraZeneca_SOW28_41Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210611_AstraZeneca_SOW84_28Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190829_AstraZeneca_SOW48_108Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210614_AstraZeneca_SOW88_11Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200213_AstraZeneca_SOW71_50Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200310_AstraZeneca_SOW69_162Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200911_AstraZeneca_SOW59_19Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191217_AstraZeneca_SOW70_287Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190816_AstraZeneca_SOW40_39Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190801_AstraZeneca_SOW50_91Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200330_AstraZeneca_SOW64_600Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210922_AstraZeneca_SOW102_9Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190214_AstraZeneca_SOW30_62Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20181012_AstraZeneca_SOW26_OMNI_14Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20180621_AstraZeneca_SOW21_82Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210310_AstraZeneca_SOW84_14Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191205_AstraZeneca_SOW63_530Samples_OMNICDxReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210217_AstraZeneca_SOW41_3Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20191107_AstraZeneca_SOW49R_3Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190917_AstraZeneca_SOW46_27Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200319_AstraZeneca_SOW46_127Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210923_AstraZeneca_SOW76_71Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20210921_AstraZeneca_SOW88_21Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200825_AstraZeneca_SOW43_146Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200820_AstraZeneca_SOW73_40Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190813_AstraZeneca_SOW45_564Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200611_AstraZeneca_SOW40_51Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190930_AstraZeneca_SOW61_92Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20200225_AstraZeneca_SOW40_26Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20190225_AstraZeneca_SOW28_160Samples_OmniReport.csv - Index(['GHSampleID'], dtype='object')
# An unexpected error occurred with file: /ghsfa/projects/pharma/datawarehouse/data/OMNI_Report_Warehouse/20201214_AstraZeneca_SOW89_280Samples_OMNIReport.csv - Index(['GHSampleID'], dtype='object')
#       Study_ID GHRequestID GHSampleID Patient_ID Visit_name Sample_status  \
# 0  D926NC00001    A0890339  B00535465   E5703003       SCRN       SUCCESS
# 1  D926NC00001    A0890340  B00535427   E4303003       SCRN       SUCCESS
# 2  D926NC00001    A0890341  B00535430   E5703001       SCRN       SUCCESS
# 3  D926NC00001    A0890342  B00535432   E2617001       SCRN       SUCCESS
# 4  D926NC00001    A0890343  B00535434   E6009008       SCRN       SUCCESS
#
#   Sample_comment  Max_percentage  cfDNA_ng  Plasma_ml_input Cancertype  \
# 0            NaN             NaN     9.620              3.0        NaN
# 1            NaN             NaN   119.600              3.5        NaN
# 2            NaN             NaN     8.788              3.0        NaN
# 3            NaN             NaN    13.000              3.5        NaN
# 4            NaN             NaN     7.332              3.5        NaN
#
#                                           csv_file_name file_creator
# 0  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 1  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 2  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 3  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 4  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser

# %%
# Readin samples 
df_merged_1 = df_merged.copy()

# Drop duplicates 
df_merged_dedup = df_merged_1.drop_duplicates(subset=["GHSampleID"])
print("Total size of this RUO/IST summary data is " + str(df_merged_dedup.shape[0]) + "\n") 

# Regular expression to extract 'Account', 'SOW_num', and 'report_date'
pattern = r'(?P<report_date>^\d+)_?(?P<Account>[^_]+)_([^_]+)'

# Using str.extract() to create new columns in the DataFrame
df_merged_dedup[['report_date', 'Account', 'SOW_num']] = df_merged_dedup['csv_file_name'].str.extract(pattern)

df_merged_dedup.head()
# Out:
# Total size of this RUO/IST summary data is 20361
#       Study_ID GHRequestID GHSampleID Patient_ID Visit_name Sample_status  \
# 0  D926NC00001    A0890339  B00535465   E5703003       SCRN       SUCCESS
# 1  D926NC00001    A0890340  B00535427   E4303003       SCRN       SUCCESS
# 2  D926NC00001    A0890341  B00535430   E5703001       SCRN       SUCCESS
# 3  D926NC00001    A0890342  B00535432   E2617001       SCRN       SUCCESS
# 4  D926NC00001    A0890343  B00535434   E6009008       SCRN       SUCCESS
#
#   Sample_comment  Max_percentage  cfDNA_ng  Plasma_ml_input Cancertype  \
# 0            NaN             NaN     9.620              3.0        NaN
# 1            NaN             NaN   119.600              3.5        NaN
# 2            NaN             NaN     8.788              3.0        NaN
# 3            NaN             NaN    13.000              3.5        NaN
# 4            NaN             NaN     7.332              3.5        NaN
#
#                                           csv_file_name file_creator  \
# 0  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 1  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 2  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 3  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
# 4  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv     produser
#
#   report_date      Account SOW_num
# 0    20231127  AstraZeneca  SOW170
# 1    20231127  AstraZeneca  SOW170
# 2    20231127  AstraZeneca  SOW170
# 3    20231127  AstraZeneca  SOW170
# 4    20231127  AstraZeneca  SOW170

# %%
# 
# df_merged_dedup_test = df_merged_dedup[df_merged_dedup["GHSampleID"] == "B00310852"]
# df_merged_dedup_test

df_merged_dedup_test = df_merged_dedup[df_merged_dedup["Patient_ID"] == "E4301002"]
df_merged_dedup_test
# Out:
#           Study_ID GHRequestID GHSampleID Patient_ID  \
# 143    D926NC00001    A0890482  B00538694   E4301002
# 381    D933AC00001    A0904208  B00548760   E4301002
# 708    D9970C00001    A1120313  B00742366   E4301002
# 713    D9970C00001    A1120318  B00742371   E4301002
# 719    D9970C00001    A1120300  B00742380   E4301002
# 729    D9970C00001    A1120296  B00742396   E4301002
# 824    D926UC00001    A1088710  B00723793   E4301002
# 13308  D9800C00001    A1106012  B00732495   E4301002
# 13315  D9800C00001    A1106019  B00732491   E4301002
# 16280  D9311C00001    A0982732  B00624859   E4301002
# 16633  D9311C00001    A0983085  B00627986   E4301002
# 16634  D9311C00001    A0983129  B00628007   E4301002
# 17118  D9970C00001    A1073740  B00699055   E4301002
# 17120  D9970C00001    A1073744  B00699070   E4301002
# 17163  D9800C00001    A1105982  B00732850   E4301002
# 17178  D9800C00001    A1105997  B00732858   E4301002
# 17254  D9311C00001    A0978659  B00630272   E4301002
# 19139  D9970C00001    A1120331  B00742392   E4301002
# 21100  D9720C00001    A0599404  B00224152   E4301002
# 21101  D9720C00001    A0599405  B00224153   E4301002
# 23113  D9350C00001    A1047873  B00679793   E4301002
# 23640  D9720C00001    A0554804  B00180018   E4301002
# 23641  D9720C00001    A0554805  B00180007   E4301002
# 23642  D9720C00001    A0554806  B00180005   E4301002
# 23643  D9720C00001    A0554807  B00180004   E4301002
# 23644  D9720C00001    A0554808  B00180003   E4301002
# 24591  D9350C00001    A1001428  B00635395   E4301002
# 26826  D7020C00001    A0609930  B00233762   E4301002
# 26947  D9350C00001    A0999517  B00633090   E4301002
# 27177  D9350C00001    A1087805  B00716007   E4301002
# 28015  D967UC00001    A0594906  B00220228   E4301002
# 28532  D7986C00001    A0953918  B00593191   E4301002
# 28552  D7986C00001    A0953938  B00593193   E4301002
# 29073  D8530C00006    A0651499  B00284957   E4301002
# 29077  D8530C00006    A0651503  B00284939   E4301002
# 29808  D8532C00001    A0516686  B00131871   E4301002
# 30406  D7986C00001    A1003125  B00638059   E4301002
# 30492  D7020C00001    A0736230  B00369408   E4301002
# 32507  D967MC00001    A0584769  B00211287   E4301002
# 32780  D967LC00001    A0512577  B00119228   E4301002
# 33314  D8990C00001    A0931582  B00583543   E4301002
# 33524  D9720C00001    A0683405  B00310852   E4301002
# 34868  D8990C00001    A0904907  B00548265   E4301002
# 35789  D9720C00001    A0554479  B00179251   E4301002
#
#                            Visit_name Sample_status  \
# 143                              SCRN       SUCCESS
# 381                              C1D1       SUCCESS
# 708                         AESCC2D15       SUCCESS
# 713                          AESCC2D1       SUCCESS
# 719                          AESCC3D1       SUCCESS
# 729                         AESCC1D15       SUCCESS
# 824                              C1D1       SUCCESS
# 13308                           S1SCR       SUCCESS
# 13315                           S1EOT       SUCCESS
# 16280                            C3D1       SUCCESS
# 16633                            C7D1       SUCCESS
# 16634                            C9D1       SUCCESS
# 17118                            SCRN       SUCCESS
# 17120                        AESCC1D8       SUCCESS
# 17163                            S1V8       SUCCESS
# 17178                            S1V2       SUCCESS
# 17254                            C1D1       SUCCESS
# 19139                        AESCC1D1       SUCCESS
# 21100                  MODULE 1 C2D15       SUCCESS
# 21101                      M1-CYCLE05       SUCCESS
# 23113                      C4D1 BROAD       SUCCESS
# 23640                            C1D1       SUCCESS
# 23641                            C1D8       SUCCESS
# 23642                            C2D1       SUCCESS
# 23643                            C3D1       SUCCESS
# 23644                           C1D15       SUCCESS
# 24591                      C2D1 BROAD       SUCCESS
# 26826                            C1D1       SUCCESS
# 26947                      C1D1 BROAD       SUCCESS
# 27177                      C1D1 BROAD       SUCCESS
# 28015                            SCRN       SUCCESS
# 28532                          C3D1AX       SUCCESS
# 28552                            SCRN       SUCCESS
# 29073                 Screening Blood       SUCCESS
# 29077  Discontinuation/on progression       SUCCESS
# 29808                       Screening       SUCCESS
# 30406                          C5D1AX       SUCCESS
# 30492                            C3D1       SUCCESS
# 32507                       Screening       SUCCESS
# 32780                       Screening       SUCCESS
# 33314                        Baseline          FAIL
# 33524                            EOT*       SUCCESS
# 34868                       Screening       SUCCESS
# 35789                            SCRN       SUCCESS
#
#                                                 Sample_comment  \
# 143                                                        NaN
# 381                                                        NaN
# 708                                                        NaN
# 713                                                        NaN
# 719                                                        NaN
# 729                                                        NaN
# 824    Low Diversity Warning; Unusual Coverage Profile Warning
# 13308                                                      NaN
# 13315                                                      NaN
# 16280                                                      NaN
# 16633                                                      NaN
# 16634                                                      NaN
# 17118                                                      NaN
# 17120                                                      NaN
# 17163                                                      NaN
# 17178                                                      NaN
# 17254                                                      NaN
# 19139                                                      NaN
# 21100                                                      NaN
# 21101                                                      NaN
# 23113                                                      NaN
# 23640                                                      NaN
# 23641                                                      NaN
# 23642                                                      NaN
# 23643                                                      NaN
# 23644                                                      NaN
# 24591                                                      NaN
# 26826                                                      NaN
# 26947                                                      NaN
# 27177                                                      NaN
# 28015                                                      NaN
# 28532                                                      NaN
# 28552                                                      NaN
# 29073                                                      NaN
# 29077                                                      NaN
# 29808                                                      NaN
# 30406                                                      NaN
# 30492                                                      NaN
# 32507                                                      NaN
# 32780                                                      NaN
# 33314                                   Possible Contamination
# 33524                                                      NaN
# 34868                                                      NaN
# 35789                                                      NaN
#
#        Max_percentage  cfDNA_ng  Plasma_ml_input  \
# 143               NaN   14.7160              NaN
# 381               NaN   10.2960              3.0
# 708               NaN       NaN              4.0
# 713               NaN       NaN              4.0
# 719               NaN       NaN              4.0
# 729               NaN       NaN              4.0
# 824              7.32    2.3200              1.0
# 13308           14.88   64.2400              4.0
# 13315           37.56   74.1700              4.0
# 16280            0.30   16.1720              3.5
# 16633            0.39   11.5440              3.0
# 16634            6.91   22.9320              3.0
# 17118            2.75   14.3000              3.5
# 17120            2.26   12.9480              3.5
# 17163             NaN   54.9000              3.5
# 17178             NaN  126.1400              3.5
# 17254            4.87   19.5520              3.0
# 19139            2.92   13.1400              4.0
# 21100             NaN    6.3140              4.0
# 21101             NaN    7.2100              4.0
# 23113             NaN   14.6300              3.5
# 23640             NaN   13.7200              3.5
# 23641             NaN   12.8800              3.5
# 23642             NaN    8.3300              3.5
# 23643             NaN    7.8400              3.5
# 23644             NaN   17.4300              3.5
# 24591             NaN   16.3100              4.0
# 26826            0.44   16.0550              2.0
# 26947            3.97   14.4950              3.5
# 27177            0.20   29.9000              1.0
# 28015            0.30   23.3350              4.0
# 28532            0.79    4.9465              3.0
# 28552            3.71    5.4860              3.0
# 29073           17.91   37.3100              4.5
# 29077            9.05   59.2150              4.5
# 29808            0.42    9.1000              3.0
# 30406            0.46    5.3365              2.5
# 30492            0.59    7.6700              3.0
# 32507            3.03   27.5600              4.0
# 32780            8.68   27.3000              2.5
# 33314             NaN   29.9000              1.0
# 33524            3.41   10.2050              4.0
# 34868            1.39  121.5500              3.5
# 35789            6.43   22.8150              3.5
#
#                            Cancertype  \
# 143                               NaN
# 381                               NaN
# 708                               NaN
# 713                               NaN
# 719                               NaN
# 729                               NaN
# 824                               NaN
# 13308                             NaN
# 13315                             NaN
# 16280              Endometrial Cancer
# 16633              Endometrial Cancer
# 16634              Endometrial Cancer
# 17118                             NaN
# 17120                             NaN
# 17163                             NaN
# 17178                             NaN
# 17254              Endometrial Cancer
# 19139                             NaN
# 21100                          Breast
# 21101                          Breast
# 23113                             NaN
# 23640                          Breast
# 23641                          Breast
# 23642                          Breast
# 23643                          Breast
# 23644                          Breast
# 24591                             NaN
# 26826                           NSCLC
# 26947                             NaN
# 27177                             NaN
# 28015                   breast cancer
# 28532  Gastric or GEJ adenocarcinoma
# 28552  Gastric or GEJ adenocarcinoma
# 29073                   Breast cancer
# 29077                   Breast cancer
# 29808                   Breast cancer
# 30406   Gastric or GEJ adenocarcinoma
# 30492                           NSCLC
# 32507                 Esophagogastric
# 32780                         Gastric
# 33314                             NaN
# 33524                          Breast
# 34868                             NaN
# 35789                          Breast
#
#                                                                      csv_file_name  \
# 143                           20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 381                           20231218_AstraZeneca_SOW157_3_465_infinityReport.csv
# 708    20240909_AstraZeneca_SOW163Monitoring_Batch2_32Samples_MonitoringReport.csv
# 713    20240909_AstraZeneca_SOW163Monitoring_Batch2_32Samples_MonitoringReport.csv
# 719    20240909_AstraZeneca_SOW163Monitoring_Batch2_32Samples_MonitoringReport.csv
# 729    20240909_AstraZeneca_SOW163Monitoring_Batch2_32Samples_MonitoringReport.csv
# 824                20240812_AstraZeneca_SOW187_Batch3_90Samples_InfinityReport.csv
# 13308      20240819_AstraZeneca_SOW184500genes_Batch1_12Samples_InfinityReport.csv
# 13315      20240819_AstraZeneca_SOW184500genes_Batch1_12Samples_InfinityReport.csv
# 16280         20240422_AstraZeneca_SOW176_Monitoring_998Samples_InfinityReport.csv
# 16633         20240422_AstraZeneca_SOW176_Monitoring_998Samples_InfinityReport.csv
# 16634         20240422_AstraZeneca_SOW176_Monitoring_998Samples_InfinityReport.csv
# 17118          20240717_AstraZeneca_SOW163_Monitoring_21Samples_InfinityReport.csv
# 17120          20240717_AstraZeneca_SOW163_Monitoring_21Samples_InfinityReport.csv
# 17163       20240822_AstraZeneca_SOW18474genes_Batch1_30Samples_InfinityReport.csv
# 17178       20240822_AstraZeneca_SOW18474genes_Batch1_30Samples_InfinityReport.csv
# 17254                    20240524_AstraZeneca_SOW176_352Samples_InfinityReport.csv
# 19139              20240904_AstraZeneca_SOW163_Batch1_10Samples_InfinityReport.csv
# 21100                        20221122_AstraZeneca_SOW103_291Samples_G360Report.csv
# 21101                        20221122_AstraZeneca_SOW103_291Samples_G360Report.csv
# 23113                          20240607_AstraZeneca_SOW147_5Samples_G360Report.csv
# 23640                        20220908_AstraZeneca_SOW103_314Samples_G360Report.csv
# 23641                        20220908_AstraZeneca_SOW103_314Samples_G360Report.csv
# 23642                        20220908_AstraZeneca_SOW103_314Samples_G360Report.csv
# 23643                        20220908_AstraZeneca_SOW103_314Samples_G360Report.csv
# 23644                        20220908_AstraZeneca_SOW103_314Samples_G360Report.csv
# 24591                          20240415_AstraZeneca_SOW147_8Samples_G360Report.csv
# 26826                         20221220_AstraZeneca_SOW128_32Samples_OMNIReport.csv
# 26947                          20240416_AstraZeneca_SOW146_8Samples_OMNIReport.csv
# 27177                         20240821_AstraZeneca_SOW146_12Samples_OMNIReport.csv
# 28015                         20221110_AstraZeneca_SOW93_257Samples_OMNIReport.csv
# 28532                         20240227_AstraZeneca_SOW150_34Samples_OMNIReport.csv
# 28552                         20240227_AstraZeneca_SOW150_34Samples_OMNIReport.csv
# 29073                          20230222_AstraZeneca_SOW98_17Samples_OMNIReport.csv
# 29077                          20230222_AstraZeneca_SOW98_17Samples_OMNIReport.csv
# 29808                        20220621_AstraZeneca_SOW105_575Samples_OMNIReport.csv
# 30406                         20240418_AstraZeneca_SOW150_12Samples_OMNIReport.csv
# 30492                         20230523_AstraZeneca_SOW128_24Samples_OMNIReport.csv
# 32507                          20221107_AstraZeneca_SOW78_15Samples_OMNIReport.csv
# 32780                         20220610_AstraZeneca_SOW75_134Samples_OMNIReport.csv
# 33314                         20240205_AstraZeneca_SOW151_10Samples_OMNIReport.csv
# 33524                         20230330_AstraZeneca_SOW102_88Samples_OMNIReport.csv
# 34868                          20231213_AstraZeneca_SOW151_3Samples_OMNIReport.csv
# 35789                         20220829_AstraZeneca_SOW102_44Samples_OMNIReport.csv
#
#       file_creator report_date      Account           SOW_num
# 143       produser    20231127  AstraZeneca            SOW170
# 381       produser    20231218  AstraZeneca            SOW157
# 708         kchang    20240909  AstraZeneca  SOW163Monitoring
# 713         kchang    20240909  AstraZeneca  SOW163Monitoring
# 719         kchang    20240909  AstraZeneca  SOW163Monitoring
# 729         kchang    20240909  AstraZeneca  SOW163Monitoring
# 824         kchang    20240812  AstraZeneca            SOW187
# 13308      hazhang    20240819  AstraZeneca    SOW184500genes
# 13315      hazhang    20240819  AstraZeneca    SOW184500genes
# 16280      ewarner    20240422  AstraZeneca            SOW176
# 16633      ewarner    20240422  AstraZeneca            SOW176
# 16634      ewarner    20240422  AstraZeneca            SOW176
# 17118      ewarner    20240717  AstraZeneca            SOW163
# 17120      ewarner    20240717  AstraZeneca            SOW163
# 17163      hazhang    20240822  AstraZeneca     SOW18474genes
# 17178      hazhang    20240822  AstraZeneca     SOW18474genes
# 17254      ewarner    20240524  AstraZeneca            SOW176
# 19139       kchang    20240904  AstraZeneca            SOW163
# 21100       kchang    20221122  AstraZeneca            SOW103
# 21101       kchang    20221122  AstraZeneca            SOW103
# 23113       kchang    20240607  AstraZeneca            SOW147
# 23640       kchang    20220908  AstraZeneca            SOW103
# 23641       kchang    20220908  AstraZeneca            SOW103
# 23642       kchang    20220908  AstraZeneca            SOW103
# 23643       kchang    20220908  AstraZeneca            SOW103
# 23644       kchang    20220908  AstraZeneca            SOW103
# 24591       kchang    20240415  AstraZeneca            SOW147
# 26826       kchang    20221220  AstraZeneca            SOW128
# 26947       kchang    20240416  AstraZeneca            SOW146
# 27177       kchang    20240821  AstraZeneca            SOW146
# 28015       kchang    20221110  AstraZeneca             SOW93
# 28532       kchang    20240227  AstraZeneca            SOW150
# 28552       kchang    20240227  AstraZeneca            SOW150
# 29073       kchang    20230222  AstraZeneca             SOW98
# 29077       kchang    20230222  AstraZeneca             SOW98
# 29808       kchang    20220621  AstraZeneca            SOW105
# 30406       kchang    20240418  AstraZeneca            SOW150
# 30492       kchang    20230523  AstraZeneca            SOW128
# 32507       kchang    20221107  AstraZeneca             SOW78
# 32780       kchang    20220610  AstraZeneca             SOW75
# 33314       kchang    20240205  AstraZeneca            SOW151
# 33524       kchang    20230330  AstraZeneca            SOW102
# 34868       kchang    20231213  AstraZeneca            SOW151
# 35789       kchang    20220829  AstraZeneca            SOW102

# %% [markdown]
# ### DO NOT RUN above! This is for sample checking. START CELL ENDS

# %%
# Readin samples 
df_merged_1 = df_merged.copy()

# Drop duplicates 
df_merged_dedup = df_merged_1.drop_duplicates(subset=["Customer_SampleID"])
print("Total size of this RUO/IST summary data is " + str(df_merged_dedup.shape[0]) + "\n") 

# Regular expression to extract 'Account', 'SOW_num', and 'report_date'
pattern = r'(?P<report_date>^\d+)_?(?P<Account>[^_]+)_([^_]+)'

# Using str.extract() to create new columns in the DataFrame
df_merged_dedup[['report_date', 'Account', 'SOW_num']] = df_merged_dedup['csv_file_name'].str.extract(pattern)

df_merged_dedup.head()
# Out:
# Total size of this RUO/IST summary data is 29828
#       Study_ID Customer_SampleID GHRequestID Patient_ID Visit_name  \
# 0  D926NC00001        6219464014    A0890339   E5703003       SCRN
# 1  D926NC00001        6802134548    A0890340   E4303003       SCRN
# 2  D926NC00001        6219464013    A0890341   E5703001       SCRN
# 3  D926NC00001        6220345986    A0890342   E2617001       SCRN
# 4  D926NC00001        6604395135    A0890343   E6009008       SCRN
#
#   Sample_status Sample_comment  Max_percentage  cfDNA_ng Plasma_ml_input  \
# 0       SUCCESS            NaN             NaN     9.620             3.0
# 1       SUCCESS            NaN             NaN   119.600             3.5
# 2       SUCCESS            NaN             NaN     8.788             3.0
# 3       SUCCESS            NaN             NaN    13.000             3.5
# 4       SUCCESS            NaN             NaN     7.332             3.5
#
#   Cancertype                                         csv_file_name  \
# 0        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 1        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 2        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 3        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
# 4        NaN  20231127_AstraZeneca_SOW170_1_188_infinityReport.csv
#
#   file_creator report_date      Account SOW_num
# 0     produser    20231127  AstraZeneca  SOW170
# 1     produser    20231127  AstraZeneca  SOW170
# 2     produser    20231127  AstraZeneca  SOW170
# 3     produser    20231127  AstraZeneca  SOW170
# 4     produser    20231127  AstraZeneca  SOW170

# %%
# Subset to 2024 batches of AZ

# Convert 'report_date' to datetime format
df_merged_dedup['report_date'] = pd.to_datetime(df_merged_dedup['report_date'], format='%Y%m%d')

# Filter for entries from the year 2024
df_merged_dedup_2024 = df_merged_dedup[df_merged_dedup['report_date'].dt.year == 2024]

# Continue with your processing...
print("Total size of this RUO/IST summary data for 2024 is " + str(df_merged_dedup_2024.shape[0]) + "\n")

df_merged_dedup_2024.head()
# Out:
# Total size of this RUO/IST summary data for 2024 is 6758
#         Study_ID Customer_SampleID GHRequestID Patient_ID Visit_name  \
# 663  D9720C00003        6604943170    A0994119   E0301019      C1D1B
# 664  D9720C00003        6604902860    A0994116   E0302017      C1D1B
# 665  D9720C00003        6604902861    A0994120   E0302018      C1D1B
# 666  D9720C00003        6604884198    A0994102   E0303008      C1D1B
# 667  D9720C00003        6604993819    A0994106   E0303010      C1D1B
#
#     Sample_status Sample_comment  Max_percentage  cfDNA_ng Plasma_ml_input  \
# 663       SUCCESS            NaN            2.63    10.036             3.5
# 664       SUCCESS            NaN            0.28     8.788             3.5
# 665       SUCCESS            NaN            0.50    11.544             4.0
# 666       SUCCESS            NaN            0.98    20.020             4.0
# 667       SUCCESS            NaN            1.58    11.492             3.5
#
#     Cancertype  \
# 663        NaN
# 664        NaN
# 665        NaN
# 666        NaN
# 667        NaN
#
#                                                               csv_file_name  \
# 663  20240612_AstraZeneca_SOW137_Amnd1_30Samples_500gene_InfinityReport.csv
# 664  20240612_AstraZeneca_SOW137_Amnd1_30Samples_500gene_InfinityReport.csv
# 665  20240612_AstraZeneca_SOW137_Amnd1_30Samples_500gene_InfinityReport.csv
# 666  20240612_AstraZeneca_SOW137_Amnd1_30Samples_500gene_InfinityReport.csv
# 667  20240612_AstraZeneca_SOW137_Amnd1_30Samples_500gene_InfinityReport.csv
#
#     file_creator report_date      Account SOW_num
# 663      ewarner  2024-06-12  AstraZeneca  SOW137
# 664      ewarner  2024-06-12  AstraZeneca  SOW137
# 665      ewarner  2024-06-12  AstraZeneca  SOW137
# 666      ewarner  2024-06-12  AstraZeneca  SOW137
# 667      ewarner  2024-06-12  AstraZeneca  SOW137

# %%
df_merged_dedup_2024.csv_file_name.nunique()
# Out:
# 117

# %%
df_merged_dedup_2024.Sample_status.value_counts()
# Out:
# SUCCESS    6661
# FAIL         97
# Name: Sample_status, dtype: int64

# %%
df_merged_dedup_2024.SOW_num.nunique()
# Out:
# 56

# %%
df_merged_dedup_2024.Sample_comment.value_counts()
# Out:
# Possible Contamination Warning                                                       82
# Low Diversity Warning                                                                76
# Methylation Suppression Warning; Methylation Bias Warning                            55
# Failed Enrichment                                                                    27
# GC Bias Warning                                                                      24
# Low On-Target Rate                                                                   21
# Possible Contamination                                                               18
# Unusual Coverage Profile Warning                                                     13
# Low Diversity Warning; Unusual Coverage Profile Warning                              10
# Methylation Bias Warning                                                              9
# Low Diversity                                                                         6
# Unusual Coverage Profile, Low Diversity                                               4
# Low Diversity Warning, Unusal Coverage Profile Warning                                4
# Low On Target Rate Warning                                                            3
# Low Diversity Warning; Methylation Suppression Warning                                3
# Low Diversity Warning; Methylation Suppression Warning; Methylation Bias Warning      2
# Low Diversity, Unusual Coverage Profile Warning                                       2
# Failed Sequencing                                                                     2
# GC Bias                                                                               2
# Low Diversity Warning; GC Bias Warning                                                1
# Low On-Target Rate Warning                                                            1
# GC Bias Warning; Unusual Coverage Profile Warning                                     1
# Unusal Coverage Profile Warning                                                       1
# Low Diversity Warning; Unusual Coverage Profile Warning; Methylation Bias Warning     1
# Low Diversity and Low On-Target Rate                                                  1
# Low Diversity, Low On-Target Rate                                                     1
# Low diversity and unusual coverage profile                                            1
# Low On-Target Rate, Low Diversity                                                     1
# Low On-Target Rate and Low Diversity                                                  1
# Unusual Sample Coverage Profile Warning                                               1
# Low Diversity Warning; GC Bias Warning; Unusual Coverage Profile Warning              1
# Low Diversity, Possible Contamination                                                 1
# Low Diversity, Unusual Sample Coverage Profile                                        1
# Enrichment Failed                                                                     1
# Gc Bias Warning                                                                       1
# Name: Sample_comment, dtype: int64

# %%
df_merged_dedup_2024_fail = df_merged_dedup_2024[df_merged_dedup_2024['Sample_status'] == "FAIL"]
print(df_merged_dedup_2024_fail.shape[0])
df_merged_dedup_2024_success = df_merged_dedup_2024[df_merged_dedup_2024['Sample_status'] == "SUCCESS"]
print(df_merged_dedup_2024_success.shape[0])
# Out:
# 97
# 6653

# %%
df_merged_dedup_2024_success.Sample_comment.value_counts()
# Out:
# Possible Contamination Warning                                                       82
# Low Diversity Warning                                                                74
# Methylation Suppression Warning; Methylation Bias Warning                            55
# GC Bias Warning                                                                      24
# Unusual Coverage Profile Warning                                                     11
# Low Diversity Warning; Unusual Coverage Profile Warning                              10
# Methylation Bias Warning                                                              9
# Low Diversity Warning, Unusal Coverage Profile Warning                                4
# Low On Target Rate Warning                                                            3
# Low On-Target Rate                                                                    2
# Low Diversity Warning; Methylation Suppression Warning                                1
# Unusal Coverage Profile Warning                                                       1
# Low On-Target Rate Warning                                                            1
# Low Diversity Warning; Methylation Suppression Warning; Methylation Bias Warning      1
# Low Diversity Warning; GC Bias Warning; Unusual Coverage Profile Warning              1
# Low Diversity Warning; Unusual Coverage Profile Warning; Methylation Bias Warning     1
# GC Bias Warning; Unusual Coverage Profile Warning                                     1
# Gc Bias Warning                                                                       1
# Unusual Sample Coverage Profile Warning                                               1
# Name: Sample_comment, dtype: int64

# %%
df_merged_dedup_2024_fail.Sample_comment.value_counts()
# Out:
# Failed Enrichment                                                                   27
# Low On-Target Rate                                                                  19
# Possible Contamination                                                              18
# Low Diversity                                                                        6
# Unusual Coverage Profile, Low Diversity                                              4
# Low Diversity, Unusual Coverage Profile Warning                                      2
# Failed Sequencing                                                                    2
# Unusual Coverage Profile Warning                                                     2
# Low Diversity Warning                                                                2
# Low Diversity Warning; Methylation Suppression Warning                               2
# GC Bias                                                                              2
# Low Diversity Warning; GC Bias Warning                                               1
# Low diversity and unusual coverage profile                                           1
# Low Diversity and Low On-Target Rate                                                 1
# Low Diversity, Low On-Target Rate                                                    1
# Low On-Target Rate, Low Diversity                                                    1
# Low On-Target Rate and Low Diversity                                                 1
# Low Diversity Warning; Methylation Suppression Warning; Methylation Bias Warning     1
# Low Diversity, Possible Contamination                                                1
# Low Diversity, Unusual Sample Coverage Profile                                       1
# Enrichment Failed                                                                    1
# Name: Sample_comment, dtype: int64

# %%
# Calculate percentage of FAIL due to Possible Contamination
total_fails = df_merged_dedup_2024[df_merged_dedup_2024['Sample_status'] == 'FAIL'].shape[0]
fails_due_to_contamination = df_merged_dedup_2024[(df_merged_dedup_2024['Sample_status'] == 'FAIL') & (df_merged_dedup_2024['Sample_comment'].str.contains('Possible Contamination', na=False))].shape[0]

if total_fails > 0:
    percentage_fails_due_to_contamination = (fails_due_to_contamination / df_merged_dedup_2024.shape[0]) * 100
else:
    percentage_fails_due_to_contamination = 0

print(f"Percentage of FAIL samples due to Possible Contamination: {percentage_fails_due_to_contamination:.2f}%")

# Calculate percentage of SUCCESS with Possible Contamination warning
total_success = df_merged_dedup_2024[df_merged_dedup_2024['Sample_status'] == 'SUCCESS'].shape[0]
success_with_contamination_warning = df_merged_dedup_2024[(df_merged_dedup_2024['Sample_status'] == 'SUCCESS') & (df_merged_dedup_2024['Sample_comment'].str.contains('Possible Contamination', na=False))].shape[0]

if total_success > 0:
    percentage_success_with_contamination_warning = (success_with_contamination_warning / df_merged_dedup_2024.shape[0]) * 100
else:
    percentage_success_with_contamination_warning = 0

print(f"Percentage of SUCCESS samples with Possible Contamination warning: {percentage_success_with_contamination_warning:.2f}%")
# Out:
# Percentage of FAIL samples due to Possible Contamination: 0.28%
# Percentage of SUCCESS samples with Possible Contamination warning: 1.21%

# %%
# Calculate the total sample size for each SOW
total_samples_per_sow = df_merged_dedup_2024.groupby('SOW_num').size().rename('Total Sample Size')

# Calculate FAIL due to Possible Contamination for each SOW
fail_contamination = df_merged_dedup_2024[(df_merged_dedup_2024['Sample_status'] == 'FAIL') &
                                          df_merged_dedup_2024['Sample_comment'].str.contains('Possible Contamination', na=False)]
fail_contamination_count = fail_contamination.groupby('SOW_num').size().rename('Total FAIL due to Possible Contamination')
fail_contamination_percentage = (fail_contamination.groupby('SOW_num').size() / total_samples_per_sow * 100).rename('Percentage of FAIL samples due to Possible Contamination')

# Calculate SUCCESS with Possible Contamination warning for each SOW
success_contamination = df_merged_dedup_2024[(df_merged_dedup_2024['Sample_status'] == 'SUCCESS') &
                                             df_merged_dedup_2024['Sample_comment'].str.contains('Possible Contamination', na=False)]
success_contamination_count = success_contamination.groupby('SOW_num').size().rename('Total SUCCESS with Possible Contamination Warning')
success_contamination_percentage = (success_contamination.groupby('SOW_num').size() / total_samples_per_sow * 100).rename('Percentage of SUCCESS samples with Possible Contamination warning')

# Combine the results into a single DataFrame
sow_contamination_analysis = pd.DataFrame({
    'Total Sample Size': total_samples_per_sow,
    'Total FAIL due to Possible Contamination': fail_contamination_count,
    'Percentage of FAIL due to Possible Contamination': fail_contamination_percentage,
    'Total SUCCESS with Possible Contamination Warning': success_contamination_count,
    'Percentage of SUCCESS with Contamination Warning': success_contamination_percentage
}).fillna(0)  # Filling NaN with 0 where no data is present for either FAIL or SUCCESS

# Display the DataFrame
# print(sow_contamination_analysis)

# Specify the path and save the DataFrame as a CSV file
file_path = f"{work_dir}/sow_contamination_analysis.csv"
sow_contamination_analysis.to_csv(file_path, index=True)
